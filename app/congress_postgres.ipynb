# %%
import numpy as np
import pandas as pd
import requests as r
import json
import psycopg2
from sqlalchemy import create_engine
import os
import getdata

# %%
propublica_token = os.environ['propublica_token']
postgres_password = os.environ['POSTGRES_PASSWORD']

# %%
members_vv, cvote_vv, memvotes_vv = getdata.get_voteview()

# %%
useragent = getdata.get_useragent()

# %%
members_pp = getdata.get_propublica(propublica_token, useragent, email = 'czj9zj@virginia.edu')

# %%
members = getdata.merge_members(members_pp= members_pp, members_vv=members_vv)

# %%
members
#This is already is third normal form
# Out:
#                   title short_title first_name middle_name   last_name suffix  \
# 0        Representative        Rep.       Alma        None       ADAMS   None
# 1        Representative        Rep.     Robert          B.    ADERHOLT   None
# 2        Representative        Rep.       Pete        None     AGUILAR   None
# 3        Representative        Rep.       Rick        None       ALLEN   None
# 4        Representative        Rep.      Colin        None      ALLRED   None
# ..                  ...         ...        ...         ...         ...    ...
# 551  Senator, 1st Class        Sen.  Elizabeth        None      WARREN   None
# 552  Senator, 1st Class        Sen.    Sheldon        None  WHITEHOUSE   None
# 553  Senator, 1st Class        Sen.      Roger        None      WICKER   None
# 554  Senator, 3rd Class        Sen.        Ron        None       WYDEN   None
# 555  Senator, 3rd Class        Sen.       Todd        None       YOUNG   None
#
#      congress chamber    icpsr state  ...                              office  \
# 0       117.0   House  21545.0    NC  ...  2436 Rayburn House Office Building
# 1       117.0   House  29701.0    AL  ...    266 Cannon House Office Building
# 2       117.0   House  21506.0    CA  ...    109 Cannon House Office Building
# 3       117.0   House  21516.0    GA  ...    570 Cannon House Office Building
# 4       117.0   House  21900.0    TX  ...    114 Cannon House Office Building
# ..        ...     ...      ...   ...  ...                                 ...
# 551     117.0  Senate  41301.0    MA  ...     309 Hart Senate Office Building
# 552     117.0  Senate  40704.0    RI  ...     530 Hart Senate Office Building
# 553     117.0  Senate  29534.0    MS  ...  555 Dirksen Senate Office Building
# 554     117.0  Senate  14871.0    OR  ...  221 Dirksen Senate Office Building
# 555     117.0  Senate  21133.0    IN  ...  185 Dirksen Senate Office Building
#
#             phone           fax missed_votes_pct votes_with_party_pct  \
# 0    202-225-1510          None             0.32                99.02
# 1    202-225-4876          None             1.51                96.24
# 2    202-225-3201          None             0.32                98.80
# 3    202-225-2823          None             3.03                90.92
# 4    202-225-2231          None             1.08                98.14
# ..            ...           ...              ...                  ...
# 551  202-224-4543          None             0.69                97.79
# 552  202-224-2921          None             1.39                99.30
# 553  202-224-6253          None             1.39                89.73
# 554  202-224-5244  202-228-2717             0.92                99.07
# 555  202-224-5623  202-226-6866             2.66                87.27
#
#     votes_against_party_pct DWNOMINATE propublica_id  \
# 0                      0.87     -0.465       A000370
# 1                      3.65      0.380       A000055
# 2                      1.09     -0.296       A000371
# 3                      8.97      0.699       A000372
# 4                      1.75     -0.432       A000376
# ..                      ...        ...           ...
# 551                    2.21     -0.753       W000817
# 552                    0.70     -0.354       W000802
# 553                   10.27      0.377       W000437
# 554                    0.93     -0.330       W000779
# 555                   12.73      0.458       Y000064
#
#                                    propublica_endpoint  \
# 0    https://api.propublica.org/congress/v1/members...
# 1    https://api.propublica.org/congress/v1/members...
# 2    https://api.propublica.org/congress/v1/members...
# 3    https://api.propublica.org/congress/v1/members...
# 4    https://api.propublica.org/congress/v1/members...
# ..                                                 ...
# 551  https://api.propublica.org/congress/v1/members...
# 552  https://api.propublica.org/congress/v1/members...
# 553  https://api.propublica.org/congress/v1/members...
# 554  https://api.propublica.org/congress/v1/members...
# 555  https://api.propublica.org/congress/v1/members...
#
#                   last_updated
# 0    2022-11-10 09:30:11 -0500
# 1    2022-11-10 09:30:10 -0500
# 2    2022-11-10 09:30:11 -0500
# 3    2022-11-10 09:30:10 -0500
# 4    2022-11-10 09:30:11 -0500
# ..                         ...
# 551  2022-10-12 09:45:23 -0400
# 552  2022-10-01 01:45:44 -0400
# 553  2022-10-01 01:45:44 -0400
# 554  2022-10-01 01:45:44 -0400
# 555  2022-10-12 09:45:24 -0400
#
# [556 rows x 36 columns]

# %%
members.head(1).T
# Out:
#                                                                          0
# title                                                       Representative
# short_title                                                           Rep.
# first_name                                                            Alma
# middle_name                                                           None
# last_name                                                            ADAMS
# suffix                                                                None
# congress                                                             117.0
# chamber                                                              House
# icpsr                                                              21545.0
# state                                                                   NC
# district                                                                12
# at_large                                                             False
# gender                                                                   F
# party                                                                    D
# date_of_birth                                                   1946-05-27
# leadership_role                                                       None
# twitter_account                                                   RepAdams
# facebook_account                                        CongresswomanAdams
# youtube_account                                                       None
# url                                                https://adams.house.gov
# rss_url                                    https://adams.house.gov/rss.xml
# seniority                                                               10
# next_election                                                         2022
# total_votes                                                          925.0
# missed_votes                                                           3.0
# total_present                                                          0.0
# office                                  2436 Rayburn House Office Building
# phone                                                         202-225-1510
# fax                                                                   None
# missed_votes_pct                                                      0.32
# votes_with_party_pct                                                 99.02
# votes_against_party_pct                                               0.87
# DWNOMINATE                                                          -0.465
# propublica_id                                                      A000370
# propublica_endpoint      https://api.propublica.org/congress/v1/members...
# last_updated                                     2022-11-03 09:30:11 -0400

# %%
members['propublica_id'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 551    False
# 552    False
# 553    False
# 554    False
# 555    False
# Name: propublica_id, Length: 556, dtype: bool

# %%
memvotes_vv
# Out:
#         congress chamber  rollnumber    icpsr  cast_code   prob
# 0            117   House           1  14066.0          6  100.0
# 1            117   House           1  14854.0          6  100.0
# 2            117   House           1  14863.0          6   99.6
# 3            117   House           1  14873.0          1  100.0
# 4            117   House           1  15019.0          1   92.8
# ...          ...     ...         ...      ...        ...    ...
# 459153       117  Senate         856  42105.0          1  100.0
# 459154       117  Senate         856  49300.0          1   99.3
# 459155       117  Senate         856  49308.0          1   99.9
# 459156       117  Senate         856  49703.0          6   92.3
# 459157       117  Senate         856  94659.0          6   86.7
#
# [459158 rows x 6 columns]

# %%
#icpsr and rollnumber
memvotes_vv.head(1).T
# Out:
#                   0
# congress        117
# chamber       House
# rollnumber        1
# icpsr       14066.0
# cast_code         6
# prob          100.0

# %%
#Chamber and rollnumbers are the primary key
# for one value of chamber and rollnumbers there is only one value of date
cvote_vv
# Out:
#       congress chamber  rollnumber        date  session  clerk_rollnumber  \
# 0          117   House           1  2021-01-03        1                 2
# 1          117   House           2  2021-01-03        1                 3
# 2          117   House           3  2021-01-04        1                 4
# 3          117   House           4  2021-01-04        1                 5
# 4          117   House           5  2021-01-04        1                 6
# ...        ...     ...         ...         ...      ...               ...
# 1718       117  Senate         852  2022-08-07        2               324
# 1719       117  Senate         853  2022-08-07        2               325
# 1720       117  Senate         854  2022-09-06        2               326
# 1721       117  Senate         855  2022-09-07        2               327
# 1722       117  Senate         856  2022-09-07        2               328
#
#       yea_count  nay_count  nominate_mid_1  nominate_mid_2  nominate_spread_1  \
# 0           216        211          -0.057           0.038              0.707
# 1           371          2           0.000           0.000              0.000
# 2           214        204           0.019          -0.125              0.711
# 3           214        196           0.020          -0.133              0.710
# 4           217        204           0.019          -0.124              0.711
# ...         ...        ...             ...             ...                ...
# 1718         50         50           0.042          -0.077              0.677
# 1719         50         50           0.042          -0.077              0.677
# 1720         48         42          -0.112           0.935              0.508
# 1721         50         44          -0.111           0.926              0.509
# 1722         48         45          -0.151          -0.989              0.359
#
#       nominate_spread_2  nominate_log_likelihood bill_number  \
# 0                 0.274                   -4.069         NaN
# 1                 0.000                    0.000       HRES1
# 2                -0.235                   -0.242       HRES8
# 3                -0.240                   -0.240       HRES8
# 4                -0.234                   -0.242       HRES8
# ...                 ...                      ...         ...
# 1718             -0.559                   -0.142      HR5376
# 1719             -0.559                   -0.142      HR5376
# 1720              0.998                   -7.606      PN1965
# 1721              1.007                   -7.614      PN1965
# 1722             -0.456                   -6.998      PN1502
#
#                    vote_result  \
# 0                       Pelosi
# 1                       Passed
# 2                       Passed
# 3                       Passed
# 4                       Passed
# ...                        ...
# 1718       Amendment Agreed to
# 1719               Bill Passed
# 1720  Cloture Motion Agreed to
# 1721      Nomination Confirmed
# 1722  Cloture Motion Agreed to
#
#                                               vote_desc  \
# 0                                                   NaN
# 1     Authorizing and directing the Speaker to admin...
# 2     Adopting the Rules of the House of Representat...
# 3     Adopting the Rules of the House of Representat...
# 4     Adopting the Rules of the House of Representat...
# ...                                                 ...
# 1718  To strike the extension of the limitation on S...
# 1719  A bill to provide for reconciliation pursuant ...
# 1720  John Z. Lee, of Illinois, to be United States ...
# 1721  John Z. Lee, of Illinois, to be United States ...
# 1722  Andre B. Mathis, of Tennessee, to be United St...
#
#                                           vote_question  dtl_desc
# 0                               Election of the Speaker       NaN
# 1                         On Agreeing to the Resolution       NaN
# 2     On Motion to Table the Motion to Postpone to a...       NaN
# 3                                 Table Motion to Refer       NaN
# 4                     On Ordering the Previous Question       NaN
# ...                                                 ...       ...
# 1718                                   On the Amendment       NaN
# 1719                             On Passage of the Bill       NaN
# 1720                              On the Cloture Motion       NaN
# 1721                                  On the Nomination       NaN
# 1722                              On the Cloture Motion       NaN
#
# [1723 rows x 18 columns]

# %%
cvote_vv.head(1).T
# Out:
#                                                0
# congress                                     117
# chamber                                    House
# rollnumber                                     1
# date                                  2021-01-03
# session                                        1
# clerk_rollnumber                               2
# yea_count                                    216
# nay_count                                    211
# nominate_mid_1                            -0.057
# nominate_mid_2                             0.038
# nominate_spread_1                          0.707
# nominate_spread_2                          0.274
# nominate_log_likelihood                   -4.069
# bill_number                                  NaN
# vote_result                               Pelosi
# vote_desc                                    NaN
# vote_question            Election of the Speaker
# dtl_desc                                     NaN

# %% [markdown]
# # Initialize Postgres

# %%
server = psycopg2.connect(
    user = 'postgres',
    password = postgres_password,
    host = 'postgres',
    port = '5432')
server.autocommit = True

# %%
cursor = server.cursor()

# %% [markdown]
# ## Create an empty database called contrans

# %%
try:
    cursor.execute("CREATE DATABASE contrans")
except:
    cursor.execute("DROP DATABASE contrans")
    cursor.execute("CREATE DATABASE contrans")

# %% [markdown]
# ## Add data to contrans DB

# %%
engine = create_engine('postgresql+psycopg2://{user}:{password}@{host}:{port}/{db}'.format(
    user = 'postgres',
    password = postgres_password,
    host = 'postgres',
    port = '5432',
    db = 'contrans'))

# %%
engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@postgres:5432/contrans)

# %%
members.to_sql('members',con = engine, if_exists = 'replace', chunksize = 1000, index = False)
memvotes_vv.to_sql('member_vote',con = engine, if_exists = 'replace', chunksize = 1000, index = False)
cvote_vv.to_sql('rollcalls',con = engine, if_exists = 'replace', chunksize = 1000, index = False)
# Out:
# 1723

# %% [markdown]
# ## Example Queries

# %%
myquery = '''
SELECT * FROM members
LIMIT 5
'''

rollcall = pd.read_sql(myquery, con=engine)
rollcall.head(2)
# Out:
#             title short_title first_name middle_name last_name suffix  \
# 0  Representative        Rep.       Alma        None     ADAMS   None
# 1  Representative        Rep.     Robert          B.  ADERHOLT   None
#
#    congress chamber    icpsr state  ...                              office  \
# 0     117.0   House  21545.0    NC  ...  2436 Rayburn House Office Building
# 1     117.0   House  29701.0    AL  ...    266 Cannon House Office Building
#
#           phone   fax missed_votes_pct votes_with_party_pct  \
# 0  202-225-1510  None             0.32                99.02
# 1  202-225-4876  None             1.51                96.24
#
#   votes_against_party_pct DWNOMINATE propublica_id  \
# 0                    0.87     -0.465       A000370
# 1                    3.65      0.380       A000055
#
#                                  propublica_endpoint  \
# 0  https://api.propublica.org/congress/v1/members...
# 1  https://api.propublica.org/congress/v1/members...
#
#                 last_updated
# 0  2022-11-10 09:30:11 -0500
# 1  2022-11-10 09:30:10 -0500
#
# [2 rows x 36 columns]

# %%
myquery = '''
SELECT * FROM rollcalls
LIMIT 5
'''
pd.read_sql(myquery, con = engine)
# Out:
#    congress chamber  rollnumber        date  session  clerk_rollnumber  \
# 0       117   House           1  2021-01-03        1                 2
# 1       117   House           2  2021-01-03        1                 3
# 2       117   House           3  2021-01-04        1                 4
# 3       117   House           4  2021-01-04        1                 5
# 4       117   House           5  2021-01-04        1                 6
#
#    yea_count  nay_count  nominate_mid_1  nominate_mid_2  nominate_spread_1  \
# 0        216        211          -0.057           0.038              0.707
# 1        371          2           0.000           0.000              0.000
# 2        214        204           0.019          -0.125              0.711
# 3        214        196           0.020          -0.133              0.710
# 4        217        204           0.019          -0.124              0.711
#
#    nominate_spread_2  nominate_log_likelihood bill_number vote_result  \
# 0              0.274                   -4.069        None      Pelosi
# 1              0.000                    0.000       HRES1      Passed
# 2             -0.235                   -0.242       HRES8      Passed
# 3             -0.240                   -0.240       HRES8      Passed
# 4             -0.234                   -0.242       HRES8      Passed
#
#                                            vote_desc  \
# 0                                               None
# 1  Authorizing and directing the Speaker to admin...
# 2  Adopting the Rules of the House of Representat...
# 3  Adopting the Rules of the House of Representat...
# 4  Adopting the Rules of the House of Representat...
#
#                                        vote_question dtl_desc
# 0                            Election of the Speaker     None
# 1                      On Agreeing to the Resolution     None
# 2  On Motion to Table the Motion to Postpone to a...     None
# 3                              Table Motion to Refer     None
# 4                  On Ordering the Previous Question     None

# %%
myquery = '''
SELECT * FROM member_vote
LIMIT 5
'''
pd.read_sql(myquery, con = engine)
# Out:
#    congress chamber  rollnumber    icpsr  cast_code   prob
# 0       117   House           1  14066.0          6  100.0
# 1       117   House           1  14854.0          6  100.0
# 2       117   House           1  14863.0          6   99.6
# 3       117   House           1  14873.0          1  100.0
# 4       117   House           1  15019.0          1   92.8
